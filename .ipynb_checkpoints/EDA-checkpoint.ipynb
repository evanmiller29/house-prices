# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test = pd.read_csv('Data/test.csv')
train = pd.read_csv('Data/train.csv')

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
test['file'] = 'test'
test['SalePrice'] = np.nan
train['file'] = 'train'

# %%
test_names = test.columns
train_names = train.columns

names_match = set(test_names) & set(train_names)

print('Length of columns in test (%s), train (%s) and the number that match between the two (%s)' %(len(test_names), len(train_names), 
                                                                                              len(names_match)))
# Out:
# Length of columns in test (82), train (82) and the number that match between the two (82)

# %%
frames = [train, test]

print ('Combining test and train into one long dataset for analysis. Please note that absence of sale price = NaN')
ttl_df = pd.concat(frames)

print ('Test was %s rows long, train was %s and the combined df is %s rows long' % (test.shape[0], train.shape[0], 
                                                                                    ttl_df.shape[0]))
# Out:
# Combining test and train into one long dataset for analysis. Please note that absence of sale price = NaN
# Test was 1459 rows long, train was 1460 and the combined df is 2919 rows long

# %%
print ('Working on the categorical varaiables. Man this is gonna suck')

s = pd.Series(pd.Categorical(ttl_df['MSSubClass']))

cats = ['1-STORY 1946 & NEWER ALL STYLES', '1-STORY 1945 & OLDER',
        '1-STORY W/FINISHED ATTIC ALL AGES', '1-1/2 STORY - UNFINISHED ALL AGES',
        '1-1/2 STORY FINISHED ALL AGES', '2-STORY 1946 & NEWER',
        '2-STORY 1945 & OLDER','2-1/2 STORY ALL AGES',
        'SPLIT OR MULTI-LEVEL', 'SPLIT FOYER',
       'DUPLEX - ALL STYLES AND AGES', '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
       '1-1/2 STORY PUD - ALL AGES', '2-STORY PUD - 1946 & NEWER',
       'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER', '2 FAMILY CONVERSION - ALL STYLES AND AGES']

s.cat.categories = cats
ttl_df['MSSubClass_cat'] = s
# Out:
# Working on the categorical varaiables. Man this is gonna suck

# %%
s = pd.value_counts(ttl_df['MSSubClass_cat'].values).to_frame().reset_index()
s.columns = ['house_type', 'count']

title = 'Occurences of each type of house'

sns.set_style("whitegrid")
ax = sns.barplot(y = "count", x = 'house_type', data=s)
ax.set(xlabel = '', ylabel = '', title = title)
ax.set_xticklabels(ax.get_xticklabels(), rotation='vertical');

# %%
analysis_sale = ttl_df.loc[lambda df: df.file == 'train', :]

# %%
ax = sns.violinplot(x="MSZoning", y="SalePrice", data=analysis_sale)
ax.set(xlabel='General zoning classification', ylabel = 'Sale Price')
plt.show()

# %%
ax = sns.violinplot(x="Condition1", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Proximity to various conditions', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="LotConfig", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Lot configuration', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="BldgType", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Building type', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="HouseStyle", y="SalePrice", data=analysis_sale)
ax.set(xlabel='House style', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="OverallQual", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Overall material and finish', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="OverallCond", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Overall condition', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="YearBuilt", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Year built', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="RoofStyle", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Roof type', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="RoofMatl", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Roof material', ylabel = 'Sale price')
plt.show()

# %%
ax = sns.violinplot(x="Exterior1st", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Exterior coating', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="Exterior2nd", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Exterior coating (additional)', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="MasVnrType", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Masaonry veneer type', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
sns.jointplot(x = 'MasVnrArea', y = 'SalePrice', kind="hex", color="#4CB391", data = analysis_sale)

# %%
sns.jointplot(x = 'LotFrontage', y = 'SalePrice', kind="hex", color="#4CB391", data = analysis_sale)

# %%
sns.jointplot(x = 'LotArea', y = 'SalePrice', kind="hex", color="#4CB391", data = analysis_sale)

# %%
ax = sns.violinplot(x="Foundation", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Foundation type', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="BsmtQual", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Basement height evaluation', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="BsmtCond", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Basement condition evaluation', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()

# %%
ax = sns.violinplot(x="BsmtFinType1", y="SalePrice", data=analysis_sale)
ax.set(xlabel='Basement condition evaluation', ylabel = 'Sale price')
plt.xticks(rotation=60)
plt.show()
